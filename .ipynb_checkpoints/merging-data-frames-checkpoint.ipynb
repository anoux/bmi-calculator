# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\random-csv-files\GDP per capita.csv")

# %%
df2 = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\random-csv-files\Land use Statistics by Country.csv")

# %%
mergeA = df1.merge(df2, how = 'inner', on = 'Country')

# %%
mergeA
# Out:
#                  Country  GDP per capita ISO-code  Unnamed: 0 Rank  \
# 0            Afghanistan          2182.0      AFG          36   36
# 1                Albania         14866.0      ALB         120  121
# 2                Algeria         16091.0      DZA          35   35
# 3                 Angola          6763.0      AGO          65   65
# 4    Antigua and Barbuda         30593.0      ATG         182  178
# ..                   ...             ...      ...         ...  ...
# 176              Vanuatu          3039.0      VUT         151  151
# 177            Venezuela         16055.0      VEN          67   67
# 178              Vietnam          8677.0      VNM          29   29
# 179                Yemen          2312.0      YEM          96   96
# 180               Zambia          4174.0      ZMB          63   63
#
#      Cultivated land (km2)  Cultivated land (%)  Arable land (km2)  \
# 0                    78916                12.10              77612
# ...

# %%
mergeB = df1.merge(df2, how = 'outer', on = 'Country')

# %%
mergeB
# Out:
#                          Country  GDP per capita ISO-code  Unnamed: 0 Rank  \
# 0                    Afghanistan          2182.0      AFG        36.0   36
# 1                        Albania         14866.0      ALB       120.0  121
# 2                        Algeria         16091.0      DZA        35.0   35
# 3                         Angola          6763.0      AGO        65.0   65
# 4            Antigua and Barbuda         30593.0      ATG       182.0  178
# ..                           ...             ...      ...         ...  ...
# 243            Clipperton Island             NaN      NaN       232.0
# 244  Ashmore and Cartier Islands             NaN      NaN       233.0
# 245               Navassa Island             NaN      NaN       234.0
# 246                       Monaco             NaN      NaN       235.0  193
# 247                 Vatican City             NaN      NaN       236.0  194
#
#      Cultivated land (km2)  Cultivated land (%)  Arable land (km2)  \
# ...
