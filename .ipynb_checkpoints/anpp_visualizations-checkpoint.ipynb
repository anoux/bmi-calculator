# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\bootcamp-alex\anpp_dataset.csv")

# %%
df = dataframe.set_index("ID Registro")

# %%
print(df.columns.values)
# Out:
# ['ID fuente' 'LAT' 'LON' 'Celda' 'Departamento, partido o comuna'
#  'Provincia' 'Espontánea' 'Recurso 1' 'Recurso 2' 'Fuente de variación'
#  'Sitioy/o condición' 'Composición florística'
#  'Composición florística simplificada (solo vegetación cultivada)'
#  'Riqueza especies' 'PPNA (kg/ha.año)' 'DesvEst interanual (n)'
#  'DesvEst interanual (kg/ha)' 'DesvEst espacial (kg/ha)'
#  'Período evaluado (años)' 'Inicio' 'Final' 'Cantidad de años evaluados'
#  'Edad (años)' 'Fertilización' 'Tratamiento'
#  'Fertilización (N) (kg/ha.año)' 'Fertilización  (P) (kg/ha.año)'
#  'Fertilización  (S) (kg/ha.año)' 'Fertilización  (K) (kg/ha.año)'
#  'Pastoreo' 'Clausura' 'Riego' 'Cantidad riego (mm)' 'Precipitación (mm)'
#  'Precipitación durante el año de medición (mm/estación de crecimiento)'
#  'Precipitación promedio mencionada en la fuente (mm)'
#  'Precip. anual promedio según SMN interpolado (mm/año)'
#  'Precipitación media anual tomada de geoportal IDESA'
# ...

# %%
df.plot(kind = 'barh', title = 'ANPP per Resource type',
        xlabel = 'Resource type', x = 'Recurso 2',
        ylabel = 'ANPP (kg/ha.year)', y = 'PPNA (kg/ha.año)')
# Out:
# <Axes: title={'center': 'ANPP per Resource type'}, xlabel='Resource type', ylabel='ANPP (kg/ha.year)'>
