# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\random-csv-files\Fertility.csv")
df2 = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\random-csv-files\GDP per capita.csv")
df3 = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\random-csv-files\Life expectancy.csv")
df4 = pd.read_csv(r"C:\Users\Anoux\Desktop\data-analysis\random-csv-files\median age.csv")

# %%
merge1 = df1.merge(df2, how = 'outer')

# %%
merge2 = df3.merge(df4, how = 'outer')

# %%
df = merge1.merge(merge2, how = 'outer')

# %%
df
# Out:
#                        Country  Fertility ISO-code  GDP per capita  \
# 0                  Afghanistan        4.5      AFG          2182.0
# 1                      Albania        1.6      ALB         14866.0
# 2                      Algeria        3.0      DZA         16091.0
# 3                      Andorra        1.3      AND             NaN
# 4                       Angola        5.5      AGO          6763.0
# ..                         ...        ...      ...             ...
# 235           Saint Barthelemy        NaN      BLM             NaN
# 236  Saint Pierre and Miquelon        NaN      SPM             NaN
# 237   Turks and Caicos Islands        NaN      TCA             NaN
# 238          Wallis and Futuna        NaN      WLF             NaN
# 239             Western Sahara        NaN      ESH             NaN
#
#      Life expectancy  Median age
# 0               64.5        27.4
# 1                NaN        32.9
# 2               76.7        28.1
# ...

# %%
df.set_index('ISO-code', inplace = True)

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='ISO-code'>, <Axes: xlabel='ISO-code'>,
#        <Axes: xlabel='ISO-code'>, <Axes: xlabel='ISO-code'>], dtype=object)

# %%
df.plot(kind = 'line', title = 'Countries comparison', subplots = True,
        xlabel = 'Country')
# Out:
# array([<Axes: xlabel='Country'>, <Axes: xlabel='Country'>,
#        <Axes: xlabel='Country'>, <Axes: xlabel='Country'>], dtype=object)

# %%
df['Life expectancy'].plot(kind = 'line', title = 'Countries comparison', 
        subplots = True,
        xlabel = 'Country')
# Out:
# array([<Axes: xlabel='Country'>], dtype=object)

# %%
df.plot.scatter(x= 'Median age', y = 'Life expectancy', s = 50, c = 'red')
# Out:
# <Axes: xlabel='Median age', ylabel='Life expectancy'>

# %%
df['Life expectancy'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Life expectancy'].plot.hist(bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot(column = ['Life expectancy', 'Median age'])
# Out:
# <Axes: >
